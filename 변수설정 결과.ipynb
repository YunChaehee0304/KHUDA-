# %% [markdown]
# # AIC

# %%
# - 소비자물가총지수
selected_variables_new = ['경제성장률(전기대비)', '매출액', '수출', '내수', '연구개발비', '소비자심리지수', '실업률',
       '가동률지수', '환율', '기준금리', 'ROE']

# %% [markdown]
# ![image.png](attachment:d5b06fa6-05a9-44aa-b359-41ae4bd49729.png)

# %% [markdown]
# ![image.png](attachment:57ad6694-e096-4ef0-bbc8-88e8c78c7750.png)

# %%
# - 기준금리
selected_variables_new = ['경제성장률(전기대비)', '매출액', '수출', '내수', '연구개발비', '소비자심리지수', '실업률',
       '가동률지수', '환율',  'ROE']

# %% [markdown]
# ![image.png](attachment:f0466a2a-c9da-4d7e-ad19-3908fb2d3e29.png)

# %% [markdown]
# ![image.png](attachment:ba1b5db4-289b-4dec-9768-6b490b41a507.png)

# %%
# - 매출액
selected_variables_new = ['경제성장률(전기대비)', '수출', '내수', '연구개발비', '소비자심리지수', '실업률',
       '가동률지수', '환율',  'ROE']

# %% [markdown]
# ![image.png](attachment:a7fd00d5-cb22-45e4-b3bf-7d00c77af3a6.png)

# %% [markdown]
# ![image.png](attachment:ad21a15c-7b73-4ddd-a235-adbf8bfff9fe.png)

# %%
# - 내수
selected_variables_new = ['경제성장률(전기대비)', '수출', '연구개발비', '소비자심리지수', '실업률',
       '가동률지수', '환율',  'ROE']

# %% [markdown]
# ![image.png](attachment:edaa35bb-7fe5-4158-970b-d1801f55b8fb.png)

# %% [markdown]
# ![image.png](attachment:78aaf55d-ea6e-4d63-8974-5245d5a14fb1.png)

# %%
# + 매출액
selected_variables_new = ['경제성장률(전기대비)', '수출', '매출액', '연구개발비', '소비자심리지수', '실업률',
       '가동률지수', '환율',  'ROE']

# %% [markdown]
# ![image.png](attachment:bbe95786-3a70-42ea-9277-2d1d54e1c888.png)

# %% [markdown]
# ![image.png](attachment:409798dd-f529-4298-a52a-4e8fe72f0432.png)

# %%
# - 환율
selected_variables_new = ['경제성장률(전기대비)', '수출', '매출액', '연구개발비', '소비자심리지수', '실업률',
       '가동률지수', 'ROE']

# %% [markdown]
# ![image.png](attachment:630889ea-264a-41b8-87ee-6a4b4cc0e72a.png)

# %% [markdown]
# ![image.png](attachment:0116681b-589f-42bb-ab45-7dbca54cd40a.png)

# %%
# - 실업률
selected_variables_new = ['경제성장률(전기대비)', '수출', '매출액', '연구개발비', '소비자심리지수', 
       '가동률지수', 'ROE']

# %% [markdown]
# ![image.png](attachment:bc070747-c3b4-4fec-9f03-ba3b56719600.png)

# %% [markdown]
# ![image.png](attachment:2325a8de-9677-4496-a68d-de5aa935872e.png)

# %%
# - 가동률지수
selected_variables_new = ['경제성장률(전기대비)', '수출', '매출액', '연구개발비', '소비자심리지수', 
        'ROE']

# %% [markdown]
# ![image.png](attachment:2ed2e50f-b113-4cf8-82f5-e0d667e3df54.png)

# %% [markdown]
# ![image.png](attachment:70ac631e-7482-4078-aa59-569028d819bf.png)

# %%
# 병오님 픽
selected_variables_new = ['매출액', '연구개발비', '소비자심리지수', 
        'ROE','실업률']

# %% [markdown]
# ![image.png](attachment:c9318f04-ff17-4e78-acda-bc952e714f23.png)

# %% [markdown]
# ![image.png](attachment:65b10645-3039-4eda-921a-d2c0a7de09d5.png)

# %% [markdown]
# # BIC

# %%
# - 소비자물가총지수
selected_variables_new = ['경제성장률(전기대비)', '매출액', '수출', '내수', '연구개발비', '소비자심리지수', '실업률',
       '가동률지수', '환율', '기준금리', 'ROE']

# %% [markdown]
# ![image.png](attachment:795f55a6-4aa7-4fef-8bea-804e637013e5.png)

# %% [markdown]
# ![image.png](attachment:a2b1d1c9-2954-452c-9c71-57548768fce1.png)

# %%
# - 기준금리
selected_variables_new = ['경제성장률(전기대비)', '매출액', '수출', '내수', '연구개발비', '소비자심리지수', '실업률',
       '가동률지수', '환율',  'ROE']

# %% [markdown]
# ![image.png](attachment:f8a9f340-884a-497d-9c78-d4cf95a3a101.png)

# %%
# - 매출액
selected_variables_new = ['경제성장률(전기대비)', '수출', '내수', '연구개발비', '소비자심리지수', '실업률',
       '가동률지수', '환율',  'ROE']

# %%
# - 내수
selected_variables_new = ['경제성장률(전기대비)', '수출', '연구개발비', '소비자심리지수', '실업률',
       '가동률지수', '환율',  'ROE']

# %%
# + 매출액
selected_variables_new = ['경제성장률(전기대비)', '수출', '매출액', '연구개발비', '소비자심리지수', '실업률',
       '가동률지수', '환율',  'ROE']

# %%
# - 환율
selected_variables_new = ['경제성장률(전기대비)', '수출', '매출액', '연구개발비', '소비자심리지수', '실업률',
       '가동률지수', 'ROE']

# %%
# - 실업률
selected_variables_new = ['경제성장률(전기대비)', '수출', '매출액', '연구개발비', '소비자심리지수', 
       '가동률지수', 'ROE']

# %% [markdown]
# ![image.png](attachment:629fbfd3-fcc9-4cd5-975e-da92c0f5aea1.png)

# %%
# - 가동률지수
selected_variables_new = ['경제성장률(전기대비)', '수출', '매출액', '연구개발비', '소비자심리지수', 
        'ROE']

# %% [markdown]
# ![image.png](attachment:7b531dcc-3ea4-46da-8d60-b2f0f15b94f6.png)

# %% [markdown]
# ![image.png](attachment:ac8a0c88-31a1-4824-8753-a5ac55b0b055.png)

# %%
# - 수출
selected_variables_new = ['경제성장률(전기대비)',  '매출액', '연구개발비', '소비자심리지수', 
        'ROE']

# %% [markdown]
# ![image.png](attachment:a7c133e6-e4bb-48c2-878d-26a459d6b0c1.png)

# %% [markdown]
# ![image.png](attachment:310c084c-54e1-4d6d-a0fe-b5793da93663.png)

# %%
# - 경제성장률
selected_variables_new = ['매출액', '연구개발비', '소비자심리지수', 
        'ROE']

# %% [markdown]
# ![image.png](attachment:a07c0642-013f-4503-b988-d9876b348a0c.png)

# %% [markdown]
# ![image.png](attachment:6d43dadc-15ec-42cb-bed1-004b65878e8e.png)

# %%
# - 소비자심리수수
selected_variables_new = ['매출액', '연구개발비', 
        'ROE']

# %% [markdown]
# ![image.png](attachment:664e9776-1b7d-458e-8190-500550fcc954.png)

# %% [markdown]
# ![image.png](attachment:9900f65c-89b1-438f-baf4-00f8d7e613eb.png)

# %%
# 병오님 픽
selected_variables_new = ['매출액', '연구개발비', '소비자심리지수', 
        'ROE','실업률']

# %% [markdown]
# ![image.png](attachment:eef923ef-2173-49dc-86e4-692f5a1f4c2c.png)

# %% [markdown]
# ![image.png](attachment:06fae635-bb4f-4719-bdf9-e5ac46da2a31.png)

# %%
# ALL, lag = 2
selected_variables_new = ['경제성장률(전기대비)', '소비자물가총지수','매출액', '수출', '내수', '연구개발비', '소비자심리지수', '실업률',
       '가동률지수', '환율', '기준금리', 'ROE']

# %% [markdown]
# ![image.png](attachment:a30ed5fc-64c5-417d-8466-288d913012a4.png)

# %% [markdown]
# ![image.png](attachment:7806ab4b-71a3-41d7-9ea9-25f87878e170.png)

# %%
# ALL, lag = 1
selected_variables_new = ['경제성장률(전기대비)', '소비자물가총지수','매출액', '수출', '내수', '연구개발비', '소비자심리지수', '실업률',
       '가동률지수', '환율', '기준금리', 'ROE']

# %% [markdown]
# ![image.png](attachment:32eb69a6-a776-4988-bb3b-632bce64a427.png)

# %%
# Lag = 3

# %% [markdown]
# ![image.png](attachment:2f26f3c0-a36b-4413-8779-957475ef810c.png)

# %%
# Lag = 4

# %% [markdown]
# ![image.png](attachment:acd9beed-07d2-412c-9f35-bb063471091c.png)

# %%
# Lag = 5

# %% [markdown]
# ![image.png](attachment:73de777e-92c0-4cae-9fc1-436c3b093f06.png)

# %%
# Lag = 6

# %% [markdown]
# ![image.png](attachment:3addefcf-eaad-4801-9a3e-cd797fb13abe.png)

# %%
# Lag = 7

# %% [markdown]
# ![image.png](attachment:ee8d80b6-3fb9-4be0-a55f-acf8281063b9.png)

# %% [markdown]
# # ROE 기준

# %%
df3 = df_diff1[['연구개발비','ROE','경제성장률(전기대비)']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df3 = df_diff1[['연구개발비','ROE','경제성장률(전기대비)']]
#
# NameError: name 'df_diff1' is not defined

# %% [markdown]
# ![image.png](attachment:f032224c-0437-4d51-aa9e-eab85ea57278.png)

# %%
df3 = df_diff1[['연구개발비','ROE','매출액']]

# %% [markdown]
# ![image.png](attachment:4fae3656-bd04-41e3-a7d8-c487b56bba58.png)

# %%
df3 = df_diff1[['연구개발비','ROE','수출']]

# %% [markdown]
# ![image.png](attachment:b22e30bf-4be1-4857-b70b-8197f837b29b.png)

# %%
df3 = df_diff1[['연구개발비','ROE','소비자심리지수']]

# %% [markdown]
# ![image.png](attachment:1a640ebe-fe1c-401c-ac07-e0605340b68d.png)

# %%
df3 = df_diff1[['연구개발비','ROE','실업률']]

# %% [markdown]
# ![image.png](attachment:c6fd87f1-27ab-4d02-a632-f85d697b5371.png)

# %% [markdown]
# # 매출액 기준

# %%
df3 = df_diff1[['매출액','ROE','경제성장률(전기대비)']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df3 = df_diff1[['매출액','ROE','경제성장률(전기대비)']]
#
# NameError: name 'df_diff1' is not defined

# %% [markdown]
# ![image.png](attachment:9d61ca83-3d8d-48d3-bbcb-686356b04a71.png)

# %%
df3 = df_diff1[['매출액','ROE','소비자물가총지수']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df3 = df_diff1[['매출액','ROE','소비자물가총지수']]
#
# NameError: name 'df_diff1' is not defined

# %% [markdown]
# ![image.png](attachment:3a8a91ff-5a98-45f9-8844-53f4a8d62239.png)

# %%
df3 = df_diff1[['매출액','ROE','수출']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 df3 = df_diff1[['매출액','ROE','수출']]
#
# NameError: name 'df_diff1' is not defined

# %% [markdown]
# ![image.png](attachment:8558c066-db45-4d49-a19a-1c5e06741686.png)

# %%
df3 = df_diff1[['매출액','ROE','내수']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df3 = df_diff1[['매출액','ROE','내수']]
#
# NameError: name 'df_diff1' is not defined

# %% [markdown]
# ![image.png](attachment:adc78ef4-fafe-4ed6-a149-b3e9af041057.png)

# %%
df3 = df_diff1[['매출액','ROE','소비자심리지수']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df3 = df_diff1[['매출액','ROE','소비자심리지수']]
#
# NameError: name 'df_diff1' is not defined

# %% [markdown]
# ![image.png](attachment:7ba82ede-abbe-4dde-963f-a355eed9219f.png)

# %%
df3 = df_diff1[['매출액','ROE','실업률']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 df3 = df_diff1[['매출액','ROE','실업률']]
#
# NameError: name 'df_diff1' is not defined

# %% [markdown]
# ![image.png](attachment:8d9f185c-a8d0-453f-8df6-5c0510d1bf3c.png)

# %%
df3 = df_diff1[['매출액','ROE','기준금리']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 df3 = df_diff1[['매출액','ROE','기준금리']]
#
# NameError: name 'df_diff1' is not defined

# %% [markdown]
# ![image.png](attachment:38a9190a-4680-4a2b-a610-37feebd02930.png)
